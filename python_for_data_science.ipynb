# %% [markdown]
# # Pandas Tutorial from Python for Data Science

# %%
import math
import collections
import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %%
# Loading iris data
import seaborn as sns
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.head() # First 5 rows
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.tail() # Last 5 rows
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
iris.dtypes # Column data types
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
iris.index # Checking the index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
# Accessing columns
iris['sepal_length'] # or iris.sepal_length
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
iris.sepal_length.values # return as an array
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.6, 5. , 4.4, 4.9, 5.4, 4.8, 4.8,
#        4.3, 5.8, 5.7, 5.4, 5.1, 5.7, 5.1, 5.4, 5.1, 4.6, 5.1, 4.8, 5. ,
#        5. , 5.2, 5.2, 4.7, 4.8, 5.4, 5.2, 5.5, 4.9, 5. , 5.5, 4.9, 4.4,
#        5.1, 5. , 4.5, 4.4, 5. , 5.1, 4.8, 5.1, 4.6, 5.3, 5. , 7. , 6.4,
#        6.9, 5.5, 6.5, 5.7, 6.3, 4.9, 6.6, 5.2, 5. , 5.9, 6. , 6.1, 5.6,
#        6.7, 5.6, 5.8, 6.2, 5.6, 5.9, 6.1, 6.3, 6.1, 6.4, 6.6, 6.8, 6.7,
#        6. , 5.7, 5.5, 5.5, 5.8, 6. , 5.4, 6. , 6.7, 6.3, 5.6, 5.5, 5.5,
#        6.1, 5.8, 5. , 5.6, 5.7, 5.7, 6.2, 5.1, 5.7, 6.3, 5.8, 7.1, 6.3,
#        6.5, 7.6, 4.9, 7.3, 6.7, 7.2, 6.5, 6.4, 6.8, 5.7, 5.8, 6.4, 6.5,
#        7.7, 7.7, 6. , 6.9, 5.6, 7.7, 6.3, 6.7, 7.2, 6.2, 6.1, 6.4, 7.2,
#        7.4, 7.9, 6.4, 6.3, 6.1, 7.7, 6.3, 6.4, 6. , 6.9, 6.7, 6.9, 5.8,
#        6.8, 6.7, 6.7, 6.3, 6.5, 6.2, 5.9])

# %%
iris.species.unique() # Unique values
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris.species.value_counts() # Frequency
# Out:
# virginica     50
# versicolor    50
# setosa        50
# Name: species, dtype: int64

# %%
iris[iris.species == 'virginica'] # Filter on columns (true/false)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  virginica
# 101           5.8          2.7           5.1          1.9  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 106           4.9          2.5           4.5          1.7  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 108           6.7          2.5           5.8          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 110           6.5          3.2           5.1          2.0  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# ...

# %%
iris[['species','sepal_length']] # Selecting multiple columns to display
# Out:
#        species  sepal_length
# 0       setosa           5.1
# 1       setosa           4.9
# 2       setosa           4.7
# 3       setosa           4.6
# 4       setosa           5.0
# ..         ...           ...
# 145  virginica           6.7
# 146  virginica           6.3
# 147  virginica           6.5
# 148  virginica           6.2
# 149  virginica           5.9
#
# [150 rows x 2 columns]

# %%
# Selecting columns and applying filters
# data[list of columns][list of conditions, each condition in parentesis]
iris[
    ['species','sepal_length']
][
    (iris.species == 'setosa') & 
    (iris.sepal_length <= 5.0)
]
# Out:
#    species  sepal_length
# 1   setosa           4.9
# 2   setosa           4.7
# 3   setosa           4.6
# 4   setosa           5.0
# 6   setosa           4.6
# 7   setosa           5.0
# 8   setosa           4.4
# 9   setosa           4.9
# 11  setosa           4.8
# 12  setosa           4.8
# 13  setosa           4.3
# 22  setosa           4.6
# 24  setosa           4.8
# 25  setosa           5.0
# 26  setosa           5.0
# 29  setosa           4.7
# 30  setosa           4.8
# 34  setosa           4.9
# 35  setosa           5.0
# 37  setosa           4.9
# 38  setosa           4.4
# 40  setosa           5.0
# 41  setosa           4.5
# 42  setosa           4.4
# 43  setosa           5.0
# 45  setosa           4.8
# 47  setosa           4.6
# 49  setosa           5.0

# %% [markdown]
# ## Creating Data Frames

# %%
# To make data frames, the most usual way is a dictionary with lists associated to each column:
number = [1,2,3,4]
names = ['Danilo','Eduardo','Renato','Andrea']
pd.DataFrame({
    'names': names,
    'numbers': number
})
# Out:
#      names  numbers
# 0   Danilo        1
# 1  Eduardo        2
# 2   Renato        3
# 3   Andrea        4

# %%
# The other way is with array of dictionaries
pd.DataFrame([
    {'name':'Danilo', 'numbers':1},
    {'name':'Eduardo', 'numbers':2},
    {'name':'Renato', 'numbers':3},
    {'name':'Andrea', 'numbers':4},
])
# Out:
#       name  numbers
# 0   Danilo        1
# 1  Eduardo        2
# 2   Renato        3
# 3   Andrea        4

# %% [markdown]
# # Plotting

# %%
# Get a summary of a data frame - numerical columns
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Pandas Data Frame have a plot() method for plotting, just have to specific columns.
iris.plot.scatter('sepal_length','sepal_width')

# %%
# But lets use ggplot that is much better
from ggplot import *

ggplot(aes(x = 'sepal_length', y = 'sepal_width', color = 'species'), data = iris) + \
    geom_point() + \
    theme_bw() + \
    ggtitle('My title')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <ggplot: (8749630021527)>

# %% [markdown]
# ## dplyr (dfply) happiness!!

# %%
from dfply import *

# %%
(iris >>
    select(X.sepal_length, X.species) >>
    mask(X.species == 'setosa') # mask is the same as filter() in R.
)
# Out:
#     sepal_length species
# 0            5.1  setosa
# 1            4.9  setosa
# 2            4.7  setosa
# 3            4.6  setosa
# 4            5.0  setosa
# 5            5.4  setosa
# 6            4.6  setosa
# 7            5.0  setosa
# 8            4.4  setosa
# 9            4.9  setosa
# 10           5.4  setosa
# 11           4.8  setosa
# 12           4.8  setosa
# 13           4.3  setosa
# 14           5.8  setosa
# 15           5.7  setosa
# 16           5.4  setosa
# 17           5.1  setosa
# 18           5.7  setosa
# 19           5.1  setosa
# 20           5.4  setosa
# 21           5.1  setosa
# 22           4.6  setosa
# 23           5.1  setosa
# 24           4.8  setosa
# 25           5.0  setosa
# 26           5.0  setosa
# 27           5.2  setosa
# 28           5.2  setosa
# 29           4.7  setosa
# 30           4.8  setosa
# 31           5.4  setosa
# 32           5.2  setosa
# 33           5.5  setosa
# 34           4.9  setosa
# 35           5.0  setosa
# ...

# %%
(
iris >>
    group_by(X.species) >>
    summarise(mean_sepal_length = X.sepal_length.mean()) >>
    arrange(X.mean_sepal_length, ascending = True)
)
# Out:
#       species  mean_sepal_length
# 0      setosa              5.006
# 1  versicolor              5.936
# 2   virginica              6.588
